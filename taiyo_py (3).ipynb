# %%
import matplotlib.pyplot as plt
import numpy as np
fig,axes=plt.subplots(2,3,tight_layout=True)
y0=[1,2,-5,2]
axes[0,0].plot(y0)
x0=np.random.normal(15,5,2000)
axes[0,1].hist(x0,bins=50)
x1=4+np.random.normal(0,2,60)
y1=4+np.random.normal(0,2,len(x1))
axes[0,2].scatter(x1,y1)
x=np.linspace(0,10,30)
y=2+2*np.sin(2*x)
axes[1,0].plot(x,y,linewidth=2.0)
axes[1,0].set(xlim=(0,10),xticks=np.arange(0,10),
              ylim=(-1,5),yticks=np.arange(-1,6))
plt.show()
